# %% [markdown]
# # Data Analysis using SQL with Postgresql

# %% [markdown]
# ## Queries using pgadmin

# %% [markdown]
# ### 1. No of employees and average salary by department

# %%
select j."Department", avg("Salary"), count("EmployeeID") as "No. of Employees"
from main_details m left join
job_details j on m."Job_Profile"=j."Job_Profile"
group by 1 
order by 2;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2. No of employees by level

# %%
select j."level", count("EmployeeID") as "No. of Employees"
from main_details m left join
job_details j on m."Job_Profile"=j."Job_Profile"
group by 1 
order by 2;

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3. No. of employees by office

# %%
select o."office_name", o."office_type", count("EmployeeID") as "No. of Employees"
from main_details m left join
office o on m."office_id"=o."office_id"
group by cube(1,2)
order by 1,3 desc;

# %% [markdown]
# ![image.png](attachment:image.png)
